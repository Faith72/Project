# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans

# %%
df_mall=pd.read_csv('Mall_Customers.csv')
df_mall.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X=df_mall.iloc[:,[2,3]].values

# %%
wcss=[]
for i in range (1,21):
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=20,random_state=1) 
    km.fit(X)
    wcss.append(km.inertia_)
wcss
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [171535.50000000003,
#  75949.15601023012,
#  45840.67661610871,
#  28165.583566629342,
#  23818.848251581334,
#  19566.5223413776,
#  15514.193134351033,
#  13010.462877862885,
#  11419.219334661446,
#  10197.267506229438,
#  9384.031622603386,
#  8589.450254704589,
#  7986.328897364151,
#  7255.161837835365,
#  6661.791133947745,
#  6271.350592885377,
#  5658.025720521314,
#  5104.982409652613,
#  4885.007557217466,
#  4544.776160848955]

# %%
plt.plot(range(1,21),wcss)
plt.title('THE ELBOW METHOD')
plt.xlabel('range')
plt.ylabel('wcss')
plt.show()

# %%
km=KMeans(n_clusters=4,init='k-means++',max_iter=300,n_init=20,random_state=1) 
y_means=km.fit_predict(x)

# %%
plt.style.use('ggplot')
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,8))
plt.scatter(x[y_means==0,0],x[y_means==0,1],s=100,c='orange')
plt.scatter(x[y_means==1,0],x[y_means==1,1],s=100,c='red')
plt.scatter(x[y_means==2,0],x[y_means==2,1],s=100,c='cyan')
plt.scatter(x[y_means==3,0],x[y_means==3,1],s=100,c='green')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],s=50,c='blue',label='data point')
plt.xlabel('Annual income')
plt.ylabel('age')
plt.title('Customer Grouping Annual Income and Age')
plt.legend()
plt.show()

# %%
X=df_mall.iloc[:,[2,4]].values

# %%
wcss=[]
for i in range (1,21):
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=20,random_state=1) 
    km.fit(X)
    wcss.append(km.inertia_)
wcss
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [171535.50000000003,
#  75949.15601023012,
#  45840.67661610871,
#  28165.583566629342,
#  23818.848251581334,
#  19566.5223413776,
#  15514.193134351033,
#  13010.462877862885,
#  11419.219334661446,
#  10197.267506229438,
#  9384.031622603386,
#  8589.450254704589,
#  7986.328897364151,
#  7255.161837835365,
#  6661.791133947745,
#  6271.350592885377,
#  5658.025720521314,
#  5104.982409652613,
#  4885.007557217466,
#  4544.776160848955]

# %%
plt.plot(range(1,21),wcss)
plt.title('THE ELBOW METHOD')
plt.xlabel('range')
plt.ylabel('wcss')
plt.show()

# %%
km=KMeans(n_clusters=4,init='k-means++',max_iter=300,n_init=20,random_state=1) 
y_means=km.fit_predict(x)

# %%
plt.style.use('ggplot')
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,8))
plt.scatter(x[y_means==0,0],x[y_means==0,1],s=100,c='pink')
plt.scatter(x[y_means==1,0],x[y_means==1,1],s=100,c='red')
plt.scatter(x[y_means==2,0],x[y_means==2,1],s=100,c='cyan')
plt.scatter(x[y_means==3,0],x[y_means==3,1],s=100,c='green')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],s=50,c='blue',label='data point')
plt.xlabel('Age')
plt.ylabel('Spending score')
plt.title('Customer Grouping Age and Spending Score')
plt.legend()
plt.show()
